# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\shashank\anaconda3\lib\site-packages (0.2.31)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\shashank\anaconda3\lib\site-packages (from yfinance) (2.1.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\shashank\anaconda3\lib\site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in c:\users\shashank\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\shashank\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\shashank\anaconda3\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\shashank\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\shashank\anaconda3\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\shashank\anaconda3\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\shashank\anaconda3\lib\site-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\shashank\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\shashank\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shashank\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\shashank\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\shashank\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shashank\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\shashank\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shashank\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shashank\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shashank\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shashank\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2023.7.22)

# %%
# Import yfinance package
import yfinance as yf

# Set the start and end date
start_date = '2023-10-1'
end_date = '2023-10-13'

# Set the ticker

ticker = 'SPY'

# Get the data
data = yf.download(ticker, start_date, end_date)

# Print 5 rows
data.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-10-06  421.970001  431.130005  420.600006  429.540009  429.540009
# 2023-10-09  427.579987  432.880005  427.010010  432.290009  432.290009
# 2023-10-10  432.940002  437.220001  432.529999  434.540009  434.540009
# 2023-10-11  435.640015  436.579987  433.179993  436.320007  436.320007
# 2023-10-12  436.950012  437.339996  431.230011  433.660004  433.660004
#
#                Volume
# Date
# 2023-10-06  113202700
# 2023-10-09   80374400
# 2023-10-10   78607300
# 2023-10-11   62451700
# 2023-10-12   81154200

# %%
# Import packages
import yfinance as yf
import pandas as pd

# Set the start and end date
#start_date = '1990-01-01'
# end_date = '2021-07-12'

# Set the start and end date
start_date = '2023-10-15'
end_date = '2023-11-2'

# Define the ticker list
tickers_list = ['AAPL', 'IBM', 'MSFT', 'WMT']

# Create placeholder for data
data = pd.DataFrame(columns=tickers_list)

# Fetch the data
for ticker in tickers_list:
    data[ticker] = yf.download(ticker, 
                               start_date,
                               end_date)['Adj Close']
    
# Print first 25 rows of the data
data.head(25)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                   AAPL         IBM        MSFT         WMT
# Date
# 2023-10-16  178.720001  139.210007  332.640015  161.210007
# 2023-10-17  177.149994  140.320007  332.059998  161.419998
# 2023-10-18  175.839996  139.970001  330.109985  161.539993
# 2023-10-19  175.460007  138.009995  331.320007  160.770004
# 2023-10-20  172.880005  137.160004  326.670013  158.759995
# 2023-10-23  173.000000  136.380005  329.320007  161.009995
# 2023-10-24  173.440002  137.789993  330.529999  163.250000
# 2023-10-25  171.100006  137.080002  340.670013  162.759995
# 2023-10-26  166.889999  143.759995  327.890015  161.770004
# 2023-10-27  168.220001  142.520004  329.809998  161.169998
# 2023-10-30  170.289993  142.630005  337.309998  163.020004
# 2023-10-31  170.770004  144.639999  338.109985  163.410004
# 2023-11-01  173.970001  145.399994  346.070007  164.869995

# %%
# Import yfinance package
import yfinance as yf

# Set the start and end date
start_date = '2023-10-15'
end_date = '2023-11-3'

# Set the ticker
ticker = 'MSFT'

# Get the data
data = yf.download(ticker, start_date, end_date)

# Print 5 rows
data.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-10-27  330.429993  336.720001  328.399994  329.809998  329.809998
# 2023-10-30  333.410004  339.450012  331.829987  337.309998  337.309998
# 2023-10-31  338.850006  339.000000  334.690002  338.109985  338.109985
# 2023-11-01  339.790009  347.420013  339.649994  346.070007  346.070007
# 2023-11-02  347.239990  348.829987  344.769989  348.320007  348.320007
#
#               Volume
# Date
# 2023-10-27  29856500
# 2023-10-30  22828100
# 2023-10-31  20265300
# 2023-11-01  28158800
# 2023-11-02  24299600

# %%
#To visualize the adjusted close price data, we can use the matplotlib library and plot method as shown below.

# Import matplotlib for plotting
import matplotlib.pyplot as plt

# Plot adjusted close price data
data['Adj Close'].plot()
plt.show()
# Out:
# C:\Users\Shashank\anaconda3\Lib\site-packages\matplotlib\axis.py:1732: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   ret = self.converter.convert(x, self.units, self)
# C:\Users\Shashank\anaconda3\Lib\site-packages\matplotlib\axis.py:1732: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   ret = self.converter.convert(x, self.units, self)
# C:\Users\Shashank\anaconda3\Lib\site-packages\matplotlib\axis.py:1484: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   return self.major.locator()
# C:\Users\Shashank\anaconda3\Lib\site-packages\matplotlib\axis.py:1484: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   return self.major.locator()
# C:\Users\Shashank\anaconda3\Lib\site-packages\matplotlib\ticker.py:218: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   return [self(value, i) for i, value in enumerate(values)]
